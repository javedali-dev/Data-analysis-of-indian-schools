# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
enrollment = pd.read_csv('data/gross-enrollment-ratio-2013-2016.csv')

# %%
enrollment
# Out:
#                       State_UT     Year  Primary_Boys  Primary_Girls  \
# 0    Andaman & Nicobar Islands  2013-14         95.88          91.97
# 1               Andhra Pradesh  2013-14         96.62          96.87
# 2            Arunachal Pradesh  2013-14        129.12         127.77
# 3                        Assam  2013-14        111.77         115.16
# 4                        Bihar  2013-14         95.03         101.15
# ..                         ...      ...           ...            ...
# 105                    Tripura  2014-15        109.50         110.49
# 106              Uttar Pradesh  2014-15         91.54          98.93
# 107                Uttaranchal  2014-15        100.11         101.02
# 108                West Bengal  2014-15        101.78         102.91
# 109                  All India  2014-15         98.85         101.43
#
#      Primary_Total  Upper_Primary_Boys  Upper_Primary_Girls  \
# 0            93.93               94.70                88.98
# ...

# %%
enrollment.dtypes
# Out:
# State_UT                   object
# Year                       object
# Primary_Boys              float64
# Primary_Girls             float64
# Primary_Total             float64
# Upper_Primary_Boys        float64
# Upper_Primary_Girls       float64
# Upper_Primary_Total       float64
# Secondary_Boys            float64
# Secondary_Girls           float64
# Secondary_Total           float64
# Higher_Secondary_Boys      object
# Higher_Secondary_Girls     object
# Higher_Secondary_Total     object
# dtype: object

# %%
enrollment.shape
# Out:
# (110, 14)

# %%
enrollment.tail()
# Out:
#           State_UT     Year  Primary_Boys  Primary_Girls  Primary_Total  \
# 105        Tripura  2014-15        109.50         110.49         109.98
# 106  Uttar Pradesh  2014-15         91.54          98.93          95.00
# 107    Uttaranchal  2014-15        100.11         101.02         100.54
# 108    West Bengal  2014-15        101.78         102.91         102.33
# 109      All India  2014-15         98.85         101.43         100.08
#
#      Upper_Primary_Boys  Upper_Primary_Girls  Upper_Primary_Total  \
# 105              118.80               122.38               120.54
# 106               68.14                82.28                74.54
# 107               84.20                87.03                85.53
# 108               96.16               110.67               103.17
# 109               87.71                95.29                91.24
#
#      Secondary_Boys  Secondary_Girls  Secondary_Total Higher_Secondary_Boys  \
# ...

# %%
filt1 = enrollment['Year'] == '2013-14'

# %%
enrollment.loc[filt1]
# Out:
#                      State_UT     Year  Primary_Boys  Primary_Girls  \
# 0   Andaman & Nicobar Islands  2013-14         95.88          91.97
# 1              Andhra Pradesh  2013-14         96.62          96.87
# 2           Arunachal Pradesh  2013-14        129.12         127.77
# 3                       Assam  2013-14        111.77         115.16
# 4                       Bihar  2013-14         95.03         101.15
# 5                  Chandigarh  2013-14         88.42          96.09
# 6                Chhattisgarh  2013-14        104.06         103.93
# 7        Dadra & Nagar Haveli  2013-14         89.50          81.89
# 8                 Daman & Diu  2013-14         87.80          89.78
# 9                       Delhi  2013-14        108.78         112.95
# 10                        Goa  2013-14        104.97         105.32
# 11                    Gujarat  2013-14        100.32         102.06
# 12                    Haryana  2013-14         96.62         100.57
# ...

# %%
filt2 = enrollment['Year'] == '2014-15'

# %%
enrollment.loc[filt2]
# Out:
#                       State_UT     Year  Primary_Boys  Primary_Girls  \
# 73   Andaman & Nicobar Islands  2014-15         92.91          88.94
# 74              Andhra Pradesh  2014-15         88.31          88.11
# 75           Arunachal Pradesh  2014-15        128.78         127.45
# 76                       Assam  2014-15        113.39         116.60
# 77                       Bihar  2014-15         98.09         104.35
# 78                  Chandigarh  2014-15         83.62          91.49
# 79                Chhattisgarh  2014-15        103.30         102.85
# 80        Dadra & Nagar Haveli  2014-15         85.41          78.78
# 81                 Daman & Diu  2014-15         83.93          87.37
# 82                       Delhi  2014-15        109.38         114.61
# 83                         Goa  2014-15        103.03         105.01
# 84                     Gujarat  2014-15         97.57         100.07
# 85                     Haryana  2014-15         95.92          99.61
# ...

# %%
filt3 = enrollment['Year'] == '2015-16'

# %%
enrollment.loc[filt3]
# Out:
#                      State_UT     Year  Primary_Boys  Primary_Girls  \
# 36  Andaman & Nicobar Islands  2015-16         91.13          86.76
# 37             Andhra Pradesh  2015-16         84.88          84.05
# 38          Arunachal Pradesh  2015-16        127.61         125.88
# 39                      Assam  2015-16        104.70         107.59
# 40                      Bihar  2015-16        104.35         111.30
# 41                 Chandigarh  2015-16         77.42          86.57
# 42               Chhattisgarh  2015-16        100.17          99.87
# 43       Dadra & Nagar Haveli  2015-16         84.69          80.21
# 44                Daman & Diu  2015-16         79.68          84.95
# 45                      Delhi  2015-16        108.04         113.93
# 46                        Goa  2015-16        100.89         104.45
# 47                    Gujarat  2015-16         95.64          99.11
# 48                    Haryana  2015-16         89.96          93.21
# ...

# %%
def extract_data(data):
    new_data = []
    for d in data:
        new_data.append(d)
    return new_data

# %%
enroll_13 = extract_data(enrollment.loc[filt1,'Primary_Boys'])
enroll_14 = extract_data(enrollment.loc[filt2,'Primary_Boys'])
enroll_15 = extract_data(enrollment.loc[filt3,'Primary_Boys'])
states = extract_data(enrollment.loc[filt3, 'State_UT'])
len(enroll_15)
# Out:
# 37

# %%
#plt.bar(states,enroll_13)
plt.bar(states,enroll_14)
plt.bar(states,enroll_15)
# Out:
# <BarContainer object of 37 artists>
